# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("Dataframe") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read the dataset
df_pyspark = spark.read.option('header', 'true').csv('test.csv', inferSchema=True)

# %%
### Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('test.csv', header=True, inferSchema=True)
df_pyspark.show()
# Out:
# +----+---+----------+
# |Name|Age|Experience|
# +----+---+----------+
# | Lan| 25|        10|
# |  An| 19|         8|
# |John| 21|         4|
# +----+---+----------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', 'Age', 'Experience']

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Lan', Age=25, Experience=10),
#  Row(Name='An', Age=19, Experience=8),
#  Row(Name='John', Age=21, Experience=4)]

# %%
df_pyspark.select(['Name', 'Experience']).show()
# Out:
# +----+----------+
# |Name|Experience|
# +----+----------+
# | Lan|        10|
# |  An|         8|
# |John|         4|
# +----+----------+

# %%
type(df_pyspark.select(['Name', 'Experience']))
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience', 'int')]

# %%
df_pyspark.describe().show()
# Out:
# +-------+----+------------------+-----------------+
# |summary|Name|               Age|       Experience|
# +-------+----+------------------+-----------------+
# |  count|   3|                 3|                3|
# |   mean|NULL|21.666666666666668|7.333333333333333|
# | stddev|NULL|3.0550504633038935|3.055050463303893|
# |    min|  An|                19|                4|
# |    max| Lan|                25|               10|
# +-------+----+------------------+-----------------+

# %%
### Adding Columns in dataframe
df_pyspark = df_pyspark.withColumn('Experience After 2 Years', df_pyspark['Experience']+2, )

# %%
df_pyspark.show()
# Out:
# +----+---+----------+------------------------+
# |Name|Age|Experience|Experience After 2 Years|
# +----+---+----------+------------------------+
# | Lan| 25|        10|                      12|
# |  An| 19|         8|                      10|
# |John| 21|         4|                       6|
# +----+---+----------+------------------------+

# %%
### Drop the column
df_pyspark = df_pyspark.drop('Experience After 2 Years')

# %%
df_pyspark.show()
# Out:
# +----+---+----------+
# |Name|Age|Experience|
# +----+---+----------+
# | Lan| 25|        10|
# |  An| 19|         8|
# |John| 21|         4|
# +----+---+----------+

# %%
### Rename the columns
df_pyspark.withColumnRenamed('Name', 'New Name').show()
# Out:
# +--------+---+----------+
# |New Name|Age|Experience|
# +--------+---+----------+
# |     Lan| 25|        10|
# |      An| 19|         8|
# |    John| 21|         4|
# +--------+---+----------+
